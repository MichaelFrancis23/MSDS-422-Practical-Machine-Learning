# %% [markdown]
# # Kaggle Titanic EDA

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('C:/Users/mfrancis/Desktop/Titanic/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Sex Variable

# %%
data.groupby(['Sex'])['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex by Survival Status')
plt.show()

# %% [markdown]
# ## Age Variable

# %%
data[['Age']].describe()
# Out:
#               Age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
sns.jointplot(x="Age", y="Fare", data=data)

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

ax[0]= sns.boxplot(x="Pclass", y="Age", data=data,ax=ax[0])
ax[0]= sns.stripplot(x="Pclass", y="Age", data=data, jitter=True, edgecolor="gray",ax=ax[0])

ax[1]= sns.boxplot(x="Survived", y="Age", data=data,ax=ax[1])
ax[1]= sns.stripplot(x="Survived", y="Age", data=data, jitter=True, edgecolor="gray",ax=ax[1])

plt.show()

# %% [markdown]
# ## Pclass Variable

# %%
data[['Pclass']].describe()
# Out:
#            Pclass
# count  891.000000
# mean     2.308642
# std      0.836071
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      3.000000
# max      3.000000

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Pclass','Survived']].groupby(['Pclass']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Pclass')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass by Survival Status')
plt.show()

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## SibSp Variable

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['SibSp','Survived']].groupby(['SibSp']).mean().plot.bar(ax=ax[0])
ax[0].set_title('SibSp')
sns.countplot('SibSp',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp by Survival Status')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

ax[0]= sns.boxplot(x="Pclass", y="SibSp", data=data,ax=ax[0])
ax[0]= sns.stripplot(x="Pclass", y="SibSp", data=data, jitter=True, edgecolor="gray",ax=ax[0])

ax[1]= sns.boxplot(x="Survived", y="SibSp", data=data,ax=ax[1])
ax[1]= sns.stripplot(x="Survived", y="SibSp", data=data, jitter=True, edgecolor="gray",ax=ax[1])

plt.show()

# %% [markdown]
# ## Parch Variable

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Parch','Survived']].groupby(['Parch']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Parch')
sns.countplot('Parch',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Parch by Survival Status')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

ax[0]= sns.boxplot(x="Pclass", y="Parch", data=data,ax=ax[0])
ax[0]= sns.stripplot(x="Pclass", y="Parch", data=data, jitter=True, edgecolor="gray",ax=ax[0])

ax[1]= sns.boxplot(x="Survived", y="Parch", data=data,ax=ax[1])
ax[1]= sns.stripplot(x="Survived", y="Parch", data=data, jitter=True, edgecolor="gray",ax=ax[1])

plt.show()

# %% [markdown]
# ## Pair Plots

# %%
sns.pairplot(data=data[["Fare","Survived","Age","Pclass"]],
             hue="Survived", dropna=True);
